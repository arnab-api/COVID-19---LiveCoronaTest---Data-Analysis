# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline 
#this line above prepares IPython notebook for working with matplotlib

# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().


import numpy as np # imports a fast numerical programming library
import scipy as sp #imports stats functions, amongst other things
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm #allows us easy access to colormaps
import matplotlib.pyplot as plt #sets up plotting under plt
import json
# plt.style.use('ggplot')

import pandas as pd #lets us handle data as dataframes

## Classifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier

## Result Analysis
from sklearn.externals import joblib
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.metrics import recall_score, precision_score, confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn import metrics


from tqdm import tqdm
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()

## For Ploting
import seaborn as sns

## Word Embedding
import gensim
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
from gensim.models import FastText
from gensim.models import doc2vec
from gensim.models.keyedvectors import KeyedVectors

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from scipy.spatial.distance import cdist

from sklearn.manifold import TSNE

from sklearn.decomposition import LatentDirichletAllocation

## File save
import pickle
# import vincent


## Natural Language Toolkit
import nltk
nltk.download('popular')

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words_nltk = set(stopwords.words('english')) 

# !pip install --user summa
# from summa import keywords
import logging
import spacy
import sys
from folium import FeatureGroup, LayerControl, Map, Marker
from datetime import datetime
# vincent.core.initialize_notebook()
import folium
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-eb0f30040fb1> in <module>
#      26
#      27 ## Result Analysis
# ---> 28 from sklearn.externals import joblib
#      29 from sklearn import preprocessing
#      30 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (/home/arnab/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/externals/__init__.py)

# %%
symptom_list = ['Abdominal pain, nausea or thin closet', 'High fever', 'Cancer', 'Itching eyes or turning red', 'Diabetes', 
                'Kidney problem', 'Difficulty in breathing', 'Muscle pain', 'Dry cough', 'Not getting smell',
                'Feeling pain and pressure in chest', 'Respiratory illness' ,'Feeling testless', 'Sleepiness', 'Fever', 
                'Sore throat', 'Heart diseases', 'Weakness', 'High blood pressure']

# %%
len(symptom_list)
# Out:
# 19

# %%
# for al in add_list:
#     df_c[al] = 0
# df_c.loc['2020-09-24'] = 0
# df_c.loc['2020-09-24', 'date'] = '2020-09-24'
# df_c

# %%
# dist_set = set()
# for sn in symptom_list:
#     df = pd.read_csv('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/Shajib-Sir-Formatted-Data/'+sn+'_Reports_over_Districts.csv', header  = 0)
    
#     dist_set.update(df.columns)
# #     df['date'] =  pd.to_datetime(df['date'],format='%Y-%m-%d') 
#     df = df[fil_col]
#     df.to_csv('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/'+sn+'.csv', index = False)
#     display(df)

# %%
### update


# for sn in symptom_list:
#     df = pd.read_csv('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/Shajib-Sir-Formatted-Data/'+sn+'_Reports_over_Districts.csv', header  = 0)
#     df.to_csv('/u/erdos/mamin17/notebooks/bsbijoy2050/Covid19/dataset/bd_covid_original/'+sn+'.csv', index = False)
#     display(df)

# %%
# for sn in symptom_list:
#     df = pd.read_csv('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/'+sn+'.csv', header  = 0)
#     df.to_csv('/u/erdos/mamin17/notebooks/bsbijoy2050/Covid19/dataset/bd_covid_processed/'+sn+'.csv', index = False)
#     display(df)

# %%
# dist_set

# %%
# len(dist_set)

# %%
dist_list = [
 'Bagerhat',
 'Bandarban',
 'Barguna',
 'Barisal',
 'Bhola',
 'Bogra',
 'Brahmanbaria',
 'Chandpur',
 'Chapainawabganj',
 'Chittagong',
 'Chuadanga',
 'Comilla',
 "Cox's Bazar",
 'Dhaka',
 'Dinajpur',
 'Faridpur',
 'Feni',
 'Gaibandha',
 'Gazipur',
 'Gopalganj',
 'Habiganj',
 'Jaipurhat',
 'Jamalpur',
 'Jessore',
 'Jhalokati',
 'Jhenaidah',
 'Khagrachhari',
 'Khulna',
 'Kishoreganj',
 'Kurigram',
 'Kushtia',
 'Lakshmipur',
 'Lalmonirhat',
 'Madaripur',
 'Magura',
 'Manikganj',
 'Maulvibazar',
 'Meherpur',
 'Munshiganj',
 'Mymensingh',
 'Naogaon',
 'Narail',
 'Narayanganj',
 'Narsingdi',
 'Natore',
 'Netrokona',
 'Nilphamari',
 'Noakhali',
 'Pabna',
 'Panchagarh',
 'Patuakhali',
 'Pirojpur',
 'Rajbari',
 'Rajshahi',
 'Rangamati',
 'Rangpur',
 'Satkhira',
 'Shariatpur',
 'Sherpur',
 'Sirajganj',
 'Sunamganj',
 'Sylhet',
 'Tangail',
 'Thakurgaon'
]

# %%
len(dist_list)
# Out:
# 64

# %%
# with open('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/district_list_bdcovid.pickle', 'wb') as handle:
#     pickle.dump(dist_list, handle)

# %%
date_set = set()
for sn in symptom_list:
    df = pd.read_csv('/mnt/mamin17/bsbijoy2050/Covid19/bdcovid/new_data_11_march/Shajib-Sir-Formatted-Data/'+sn+'_Reports_over_Districts.csv', header  = 0)
    
    date_set.update(df.date.values.tolist())
    print(sn)
#     df['date'] =  pd.to_datetime(df['date'],format='%Y-%m-%d') 
    
#     display(df)
    print(df.shape)
#     print()
#     print(len(set(dist_list) & set(list(df.columns))))
    print(list(df.columns))
# Out:
# Abdominal pain, nausea or thin closet
# (310, 67)
# ['date', 'Brahmanbaria', 'Satkhira', 'Chittagong', 'Magura', 'Kushtia', 'Chandpur', 'Panchagarh', 'Mymensingh', 'Nilphamari', 'Narail', 'Gopalganj', 'Manikganj', 'Unknown', 'Meherpur', 'Ã\xa0Â¦Å\x93Ã\xa0Â¦Â¾Ã\xa0Â¦Â®Ã\xa0Â¦Â¾Ã\xa0Â¦Â²Ã\xa0Â¦ÂªÃ\xa0Â§Â\x81Ã\xa0Â¦Â°', 'Feni', 'Noakhali', 'Barguna', 'Gazipur', 'Pirojpur', 'Jamalpur', 'Dhaka', 'Natore', 'Chuadanga', 'Madaripur', 'Rangpur', 'Narsingdi', 'Bogra', "Cox's Bazar", 'Naogaon', 'Sunamganj', 'Jaipurhat', 'Bhola', 'Comilla', 'Khagrachhari', 'Rajbari', 'Dinajpur', 'Faridpur', 'Sylhet', 'Chapainawabganj', 'Rajshahi', 'Munshiganj', 'Sherpur', 'Pabna', 'Rangamati', 'Thakurgaon', 'Habiganj', 'Sirajganj', 'Jhenaidah', 'Netrokona', 'Tangail', 'Bagerhat', 'Barisal', 'Gaibandha', 'Kishoreganj', 'Bandarban', 'Kurigram', 'Shariatpur', 'Lalmonirhat', 'Lakshmipur', 'Narayanganj', 'Jessore', 'Maulvibazar', 'Khulna', 'Jhalokati', 'Patuakhali']
# High fever
# (308, 66)
# ...

# %%
date_set
# Out:
# {'2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
# ...

# %%
len(date_set)
# Out:
# 310
